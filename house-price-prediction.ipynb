# %%
import numpy as np
import pandas as pd

df = pd.read_csv('house-price-data.csv')

print("first 20 rows of the dataset:")
print(df.head(20))

print("last 20 rows of the dataset:")

print(df.tail(20))
# Out:
# first 20 rows of the dataset:
#       area  bedrooms    price
# 0   1.4364         4  49.7850
# 1   2.8768         3  57.8338
# 2   2.3300         1  42.9877
# 3   1.9966         4  54.2270
# 4   0.8900         4  43.0164
# 5   0.8900         3  40.1743
# 6   0.6452         1  26.9876
# 7   2.6654         3  55.6150
# 8   2.0028         1  41.3773
# 9   2.2702         5  63.1628
# 10  0.5515         2  31.7339
# 11  2.9248         2  55.1922
# 12  2.5811         2  49.5676
# 13  1.0308         3  39.4682
# 14  0.9546         5  50.6666
# 15  0.9585         1  30.5007
# 16  1.2606         4  47.5747
# 17  1.8119         1  38.2949
# 18  1.5799         4  52.7151
# 19  1.2281         1  31.3934
# last 20 rows of the dataset:
#        area  bedrooms    price
# 180  1.3527         5  52.7309
# 181  0.7837         4  41.9731
# 182  2.8117         2  52.7048
# 183  2.6933         1  43.4806
# 184  1.1449         4  44.1758
# 185  2.1500         3  53.5499
# 186  2.5431         4  62.8980
# 187  1.8880         4  53.5065
# 188  1.8241         2  44.1061
# 189  1.1046         3  41.5132
# 190  0.7328         4  46.9459
# 191  2.7430         1  49.1098
# 192  2.7510         1  47.3186
# 193  2.0828         5  59.3942
# 194  1.3476         3  41.0661
# 195  1.3730         3  44.0354
# 196  2.3149         5  62.0144
# 197  2.7428         4  60.2944
# 198  2.7177         3  56.2073
# 199  2.4497         1  42.8746

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['area'], df['bedrooms'], df['price'], alpha=0.5)
ax.set_title('Price vs. Square Footage vs. Bedrooms')
ax.set_xlabel('Square Footage')
ax.set_ylabel('bedrooms')
ax.set_zlabel('price')
plt.show()
